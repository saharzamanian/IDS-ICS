# %%
import pandas as pd
import numpy as np
import keras
import time
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense, Dropout, GRU
from keras.optimizers import SGD
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense
from keras.layers import SimpleRNN, LSTM
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix
from imblearn.over_sampling import SMOTE
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.layers import Bidirectional
from sklearn.preprocessing import Normalizer
from sklearn.utils.class_weight import compute_class_weight
from sklearn.ensemble import RandomForestClassifier
#============================================

# Load the dataset to understand its structure
file_path = 'Dataset.csv'
dataset = pd.read_csv(file_path)

# Check the data types and missing values
dataset_info = dataset.info()

# Analyze the distribution of target labels
label_columns = ['IT_M_Label', 'NST_M_Label']
label_distribution = dataset[label_columns].apply(pd.Series.value_counts)

print(dataset_info, label_distribution)

#=================================================

#Preprocessing

# Fill missing values
dataset.ffill(axis=0, inplace=True)  # Forward fill to duplicate rows

# Convert categorical labels to numerical format
label_mapping = {
    'Normal': 0,
    'ddos': 1,
    'ip-scan': 2,
    'mitm': 3,
    'port-scan': 4,
    'replay': 5
}
dataset['IT_M_Label'] = dataset['IT_M_Label'].map(label_mapping)
dataset['NST_M_Label'] = dataset['NST_M_Label'].map(label_mapping)

# Drop irrelevant columns
columns_to_drop = ['sAddress', 'rAddress', 'sMACs', 'rMACs', 'sIPs', 'rIPs', 'startDate', 'endDate']
dataset_cleaned = dataset.drop(columns=columns_to_drop)

# One-hot encode the 'protocol' column
dataset_encoded = pd.get_dummies(dataset_cleaned, columns=['protocol'])

# Perform correlation analysis
correlation_matrix = dataset_encoded.corr()

# Display correlation with the target labels
correlation_with_target = correlation_matrix[['IT_B_Label', 'NST_B_Label']]

# Separate features and label
X_train = dataset_encoded.drop(columns=['IT_B_Label', 'IT_M_Label', 'NST_B_Label', 'NST_M_Label'])
Y_train = dataset_cleaned['IT_B_Label']  # Binary

#print(X_train,Y_train)

sc = MinMaxScaler(feature_range=(0,1))
X_train = sc.fit_transform(X_train)

#Balancing the dataset
smote = SMOTE(random_state=42)
X_train, Y_train = smote.fit_resample(X_train, Y_train)

X_train = np.reshape(X_train, (X_train.shape[0], 1, X_train.shape[1]))

X_train, X_test, Y_train, Y_test = train_test_split(X_train, Y_train, test_size=0.3, random_state=42)

print("Input size: ", X_train.shape[2])

# Hyperparameters
training_epochs = 50
learning_rate = 0.01

model = Sequential()
model.add(Bidirectional(LSTM(32, return_sequences=True, input_shape=(1, X_train.shape[2]), activation='relu', recurrent_activation='sigmoid', use_bias=True)))
model.add(Dropout(0.2))
model.add(Bidirectional(LSTM(16, return_sequences=True, activation='relu', recurrent_activation='sigmoid', use_bias=True)))
model.add(Dropout(0.2))
model.add(Bidirectional(LSTM(8, activation='relu', recurrent_activation='sigmoid', use_bias=True)))
model.add(Dropout(0.2))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy',
              optimizer= SGD(learning_rate= learning_rate, decay=1e-5, momentum=0.9, nesterov=True),
              #Adam(learning_rate=0.001),
              metrics=['accuracy'])

import datetime
start = datetime.datetime.now()

history = model.fit(X_train, Y_train,
                    epochs=training_epochs,
                    batch_size=32, validation_split=0.1, verbose=1)

end = datetime.datetime.now()
elapsed = end - start
print('Total Training Time : ', str(elapsed))

# Evaluate the model
loss, accuracy = model.evaluate(X_test, Y_test)
Y_pred = (model.predict(X_test) > 0.5).astype("int32")

# Calculate metrics
precision = precision_score(Y_test, Y_pred)
recall = recall_score(Y_test, Y_pred)
f1 = f1_score(Y_test, Y_pred)

# Calculate confusion matrix
tn, fp, fn, tp = confusion_matrix(Y_test, Y_pred).ravel()

# Calculate DR and FPR
dr = tp / (tp + fn)  # Detection Rate
fpr = fp / (fp + tn)  # False Positive Rate

print(f"Accuracy on Test Set: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1-Score: {f1}")
print(f"Detection Rate (DR): {dr}")
print(f"False Positive Rate (FPR): {fpr}")

model.summary()

Start = time.time()
score = model.evaluate(X_train, Y_train, batch_size=32)
End = time.time()
Elapsed = End - Start
print('Total Testing Time : ' , str(Elapsed))

# Plot accuracy
plt.figure(figsize=(10, 6))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.grid(True)
plt.savefig('acc.png')
plt.show()

# Plot loss
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')
plt.grid(True)
plt.savefig('loss.png')
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45718 entries, 0 to 45717
# Data columns (total 64 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   sAddress         45718 non-null  object
#  1   rAddress         45718 non-null  object
#  2   sMACs            45718 non-null  object
#  3   rMACs            45718 non-null  object
#  4   sIPs             44156 non-null  object
#  5   rIPs             44156 non-null  object
#  6   protocol         45718 non-null  object
#  7   startDate        45718 non-null  object
#  8   endDate          45718 non-null  object
#  9   start            45718 non-null  float64
#  10  end              45718 non-null  float64
#  11  startOffset      45718 non-null  float64
#  12  endOffset        45718 non-null  float64
#  13  duration         45718 non-null  float64
#  14  sPackets         45718 non-null  int64
#  15  rPackets         45718 non-null  int64
#  16  sBytesSum        45718 non-null  int64
#  17  rBytesSum        45718 non-null  int64
#  18  sBytesMax        44986 non-null  float64
#  19  rBytesMax        45056 non-null  float64
#  20  sBytesMin        44986 non-null  float64
#  21  rBytesMin        45056 non-null  float64
#  22  sBytesAvg        44986 non-null  float64
#  23  rBytesAvg        45056 non-null  float64
#  24  sLoad            45718 non-null  float64
#  25  rLoad            45718 non-null  float64
#  26  sPayloadSum      45718 non-null  int64
#  27  rPayloadSum      45718 non-null  int64
#  28  sPayloadMax      44986 non-null  float64
#  29  rPayloadMax      45056 non-null  float64
#  30  sPayloadMin      44986 non-null  float64
#  31  rPayloadMin      45056 non-null  float64
#  32  sPayloadAvg      44986 non-null  float64
#  33  rPayloadAvg      45056 non-null  float64
#  34  sInterPacketAvg  43317 non-null  float64
#  35  rInterPacketAvg  44444 non-null  float64
#  36  sttl             43860 non-null  float64
#  37  rttl             43983 non-null  float64
#  38  sAckRate         43860 non-null  float64
#  39  rAckRate         43983 non-null  float64
#  40  sUrgRate         43860 non-null  float64
#  41  rUrgRate         43983 non-null  float64
#  42  sFinRate         43860 non-null  float64
#  43  rFinRate         43983 non-null  float64
#  44  sPshRate         43860 non-null  float64
#  45  rPshRate         43983 non-null  float64
#  46  sSynRate         43860 non-null  float64
#  47  rSynRate         43983 non-null  float64
#  48  sRstRate         43860 non-null  float64
#  49  rRstRate         43983 non-null  float64
#  50  sWinTCP          43860 non-null  float64
#  51  rWinTCP          43983 non-null  float64
#  52  sFragmentRate    43870 non-null  float64
#  53  rFragmentRate    44145 non-null  float64
#  54  sAckDelayMax     43450 non-null  float64
#  55  rAckDelayMax     42443 non-null  float64
#  56  sAckDelayMin     43450 non-null  float64
#  57  rAckDelayMin     42443 non-null  float64
#  58  sAckDelayAvg     43450 non-null  float64
#  59  rAckDelayAvg     42443 non-null  float64
#  60  IT_B_Label       45718 non-null  int64
#  61  IT_M_Label       45718 non-null  object
#  62  NST_B_Label      45718 non-null  int64
#  63  NST_M_Label      45718 non-null  object
# dtypes: float64(45), int64(8), object(11)
# memory usage: 22.3+ MB
# None            IT_M_Label  NST_M_Label
# Normal          30236        36706
# ddos             4221         1934
# ip-scan           712          192
# mitm             3014         2584
# port-scan        3235         1944
# replay           4300         2358
# Input size:  56
# Epoch 1/50
# /opt/homebrew/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:205: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# /opt/homebrew/lib/python3.11/site-packages/keras/src/optimizers/base_optimizer.py:34: UserWarning: Argument `decay` is no longer supported and will be ignored.
#   warnings.warn(
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step - accuracy: 0.4985 - loss: 0.6932 - val_accuracy: 0.5051 - val_loss: 0.6925
# Epoch 2/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.5177 - loss: 0.6925 - val_accuracy: 0.4949 - val_loss: 0.6913
# Epoch 3/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.5565 - loss: 0.6900 - val_accuracy: 0.6579 - val_loss: 0.6727
# Epoch 4/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7021 - loss: 0.6078 - val_accuracy: 0.7947 - val_loss: 0.4390
# Epoch 5/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7790 - loss: 0.4564 - val_accuracy: 0.7949 - val_loss: 0.4294
# Epoch 6/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7857 - loss: 0.4462 - val_accuracy: 0.7940 - val_loss: 0.4285
# Epoch 7/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7884 - loss: 0.4374 - val_accuracy: 0.7957 - val_loss: 0.4076
# Epoch 8/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7853 - loss: 0.4125 - val_accuracy: 0.7926 - val_loss: 0.3481
# Epoch 9/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7912 - loss: 0.3655 - val_accuracy: 0.8016 - val_loss: 0.3379
# Epoch 10/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7951 - loss: 0.3553 - val_accuracy: 0.8280 - val_loss: 0.3281
# Epoch 11/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8040 - loss: 0.3538 - val_accuracy: 0.8351 - val_loss: 0.3232
# Epoch 12/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8073 - loss: 0.3423 - val_accuracy: 0.8311 - val_loss: 0.3147
# Epoch 13/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8173 - loss: 0.3321 - val_accuracy: 0.8325 - val_loss: 0.3090
# Epoch 14/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8144 - loss: 0.3344 - val_accuracy: 0.8214 - val_loss: 0.3152
# Epoch 15/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8172 - loss: 0.3303 - val_accuracy: 0.8162 - val_loss: 0.3232
# Epoch 16/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8085 - loss: 0.3391 - val_accuracy: 0.8287 - val_loss: 0.3191
# Epoch 17/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8140 - loss: 0.3302 - val_accuracy: 0.8290 - val_loss: 0.3073
# Epoch 18/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8134 - loss: 0.3274 - val_accuracy: 0.8368 - val_loss: 0.3086
# Epoch 19/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8139 - loss: 0.3229 - val_accuracy: 0.8365 - val_loss: 0.3116
# Epoch 20/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8191 - loss: 0.3223 - val_accuracy: 0.8197 - val_loss: 0.3211
# Epoch 21/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8118 - loss: 0.3286 - val_accuracy: 0.8285 - val_loss: 0.3041
# Epoch 22/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8144 - loss: 0.3247 - val_accuracy: 0.8025 - val_loss: 0.3074
# Epoch 23/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8146 - loss: 0.3224 - val_accuracy: 0.8271 - val_loss: 0.2962
# Epoch 24/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8120 - loss: 0.3211 - val_accuracy: 0.8356 - val_loss: 0.3022
# Epoch 25/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8191 - loss: 0.3118 - val_accuracy: 0.8372 - val_loss: 0.3048
# Epoch 26/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8219 - loss: 0.3129 - val_accuracy: 0.8216 - val_loss: 0.2956
# Epoch 27/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8237 - loss: 0.3078 - val_accuracy: 0.8257 - val_loss: 0.2912
# Epoch 28/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8153 - loss: 0.3131 - val_accuracy: 0.8287 - val_loss: 0.2944
# Epoch 29/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8153 - loss: 0.3096 - val_accuracy: 0.8372 - val_loss: 0.2866
# Epoch 30/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8147 - loss: 0.3102 - val_accuracy: 0.8290 - val_loss: 0.2987
# Epoch 31/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8162 - loss: 0.3066 - val_accuracy: 0.8339 - val_loss: 0.2911
# Epoch 32/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8226 - loss: 0.3023 - val_accuracy: 0.8353 - val_loss: 0.2805
# Epoch 33/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8253 - loss: 0.2992 - val_accuracy: 0.8346 - val_loss: 0.2804
# Epoch 34/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8267 - loss: 0.2994 - val_accuracy: 0.8202 - val_loss: 0.2960
# Epoch 35/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8262 - loss: 0.3004 - val_accuracy: 0.8292 - val_loss: 0.2827
# Epoch 36/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8223 - loss: 0.2972 - val_accuracy: 0.8377 - val_loss: 0.2766
# Epoch 37/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8220 - loss: 0.2996 - val_accuracy: 0.8342 - val_loss: 0.2826
# Epoch 38/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8194 - loss: 0.3073 - val_accuracy: 0.8051 - val_loss: 0.2949
# Epoch 39/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8231 - loss: 0.2980 - val_accuracy: 0.8346 - val_loss: 0.2862
# Epoch 40/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8243 - loss: 0.2973 - val_accuracy: 0.8384 - val_loss: 0.2782
# Epoch 41/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8267 - loss: 0.3033 - val_accuracy: 0.8377 - val_loss: 0.2823
# Epoch 42/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8277 - loss: 0.3013 - val_accuracy: 0.8174 - val_loss: 0.3120
# Epoch 43/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8237 - loss: 0.3040 - val_accuracy: 0.8160 - val_loss: 0.2991
# Epoch 44/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8247 - loss: 0.3014 - val_accuracy: 0.8325 - val_loss: 0.2820
# Epoch 45/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8284 - loss: 0.2974 - val_accuracy: 0.8365 - val_loss: 0.2827
# Epoch 46/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8258 - loss: 0.3002 - val_accuracy: 0.8344 - val_loss: 0.2860
# Epoch 47/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8276 - loss: 0.2996 - val_accuracy: 0.8363 - val_loss: 0.2783
# Epoch 48/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8287 - loss: 0.2973 - val_accuracy: 0.8372 - val_loss: 0.2805
# Epoch 49/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8198 - loss: 0.3056 - val_accuracy: 0.8344 - val_loss: 0.2805
# Epoch 50/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8270 - loss: 0.2963 - val_accuracy: 0.8382 - val_loss: 0.2742
# Total Training Time :  0:01:08.875633
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 0s 348us/step - accuracy: 0.8316 - loss: 0.2748
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 1s 725us/step
# Accuracy on Test Set: 0.8318818211555481
# Precision: 0.7547735251305763
# Recall: 0.9793356293745139
# F1-Score: 0.8525145067698259
# Detection Rate (DR): 0.9793356293745139
# False Positive Rate (FPR): 0.3133136418334974
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape              ┃    Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━┩
# │ bidirectional_7 (Bidirectional) │ (None, 1, 64)             │     22,784 │
# ├─────────────────────────────────┼───────────────────────────┼────────────┤
# │ dropout_9 (Dropout)             │ (None, 1, 64)             │          0 │
# ├─────────────────────────────────┼───────────────────────────┼────────────┤
# │ bidirectional_8 (Bidirectional) │ (None, 1, 32)             │     10,368 │
# ├─────────────────────────────────┼───────────────────────────┼────────────┤
# │ dropout_10 (Dropout)            │ (None, 1, 32)             │          0 │
# ├─────────────────────────────────┼───────────────────────────┼────────────┤
# │ bidirectional_9 (Bidirectional) │ (None, 16)                │      2,624 │
# ├─────────────────────────────────┼───────────────────────────┼────────────┤
# │ dropout_11 (Dropout)            │ (None, 16)                │          0 │
# ├─────────────────────────────────┼───────────────────────────┼────────────┤
# │ dense_5 (Dense)                 │ (None, 1)                 │         17 │
# └─────────────────────────────────┴───────────────────────────┴────────────┘
#  Total params: 71,588 (279.64 KB)
#  Trainable params: 35,793 (139.82 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 35,795 (139.83 KB)
# 1323/1323 ━━━━━━━━━━━━━━━━━━━━ 0s 348us/step - accuracy: 0.8328 - loss: 0.2753
# Total Testing Time :  0.4793050289154053
