# %%
import pandas as pd
import numpy as np
import keras
import time
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense, Dropout, GRU
from keras.optimizers import SGD
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense
from keras.layers import SimpleRNN, LSTM
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix
from imblearn.over_sampling import SMOTE
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.layers import Bidirectional
from sklearn.preprocessing import Normalizer
from sklearn.utils.class_weight import compute_class_weight
from sklearn.ensemble import RandomForestClassifier
#============================================

# Load the dataset to understand its structure
file_path = 'Dataset.csv'
dataset = pd.read_csv(file_path)

# Check the data types and missing values
dataset_info = dataset.info()

# Analyze the distribution of target labels
label_columns = ['IT_M_Label', 'NST_M_Label']
label_distribution = dataset[label_columns].apply(pd.Series.value_counts)

print(dataset_info, label_distribution)

#=================================================

#Preprocessing

# Fill missing values
dataset.ffill(axis=0, inplace=True)  # Forward fill to duplicate rows

# Convert categorical labels to numerical format
label_mapping = {
    'Normal': 0,
    'ddos': 1,
    'ip-scan': 2,
    'mitm': 3,
    'port-scan': 4,
    'replay': 5
}
dataset['IT_M_Label'] = dataset['IT_M_Label'].map(label_mapping)
dataset['NST_M_Label'] = dataset['NST_M_Label'].map(label_mapping)

# Drop irrelevant columns
columns_to_drop = ['sAddress', 'rAddress', 'sMACs', 'rMACs', 'sIPs', 'rIPs', 'startDate', 'endDate']
dataset_cleaned = dataset.drop(columns=columns_to_drop)

# One-hot encode the 'protocol' column
dataset_encoded = pd.get_dummies(dataset_cleaned, columns=['protocol'])

# Perform correlation analysis
correlation_matrix = dataset_encoded.corr()

# Display correlation with the target labels
correlation_with_target = correlation_matrix[['IT_B_Label', 'NST_B_Label']]

# Separate features and label
X_train = dataset_encoded.drop(columns=['IT_B_Label', 'IT_M_Label', 'NST_B_Label', 'NST_M_Label'])
Y_train = dataset_cleaned['IT_B_Label']  # Binary

#print(X_train,Y_train)

sc = MinMaxScaler(feature_range=(0,1))
X_train = sc.fit_transform(X_train)

#Balancing the dataset
smote = SMOTE(random_state=42)
X_train, Y_train = smote.fit_resample(X_train, Y_train)

X_train = np.reshape(X_train, (X_train.shape[0], 1, X_train.shape[1]))

X_train, X_test, Y_train, Y_test = train_test_split(X_train, Y_train, test_size=0.3, random_state=42)

print("Input size: ", X_train.shape[2])

# Hyperparameters
training_epochs = 50
learning_rate = 0.01

model = Sequential()
model.add(LSTM(32, return_sequences=True, input_shape=(1, X_train.shape[2]), activation='relu', recurrent_activation='sigmoid', use_bias=True))
model.add(Dropout(0.2))
model.add(LSTM(16, return_sequences=True, activation='relu', recurrent_activation='sigmoid', use_bias=True))
model.add(Dropout(0.2))
model.add(LSTM(8, activation='relu', recurrent_activation='sigmoid', use_bias=True))
model.add(Dropout(0.2))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy',
              optimizer= SGD(learning_rate= learning_rate, decay=1e-5, momentum=0.9, nesterov=True),
              #Adam(learning_rate=0.001),
              metrics=['accuracy'])

import datetime
start = datetime.datetime.now()

history = model.fit(X_train, Y_train,
                    epochs=training_epochs,
                    batch_size=32, validation_split=0.1, verbose=1)

end = datetime.datetime.now()
elapsed = end - start
print('Total Training Time : ', str(elapsed))

# Evaluate the model
loss, accuracy = model.evaluate(X_test, Y_test)
Y_pred = (model.predict(X_test) > 0.5).astype("int32")

# Calculate metrics
precision = precision_score(Y_test, Y_pred)
recall = recall_score(Y_test, Y_pred)
f1 = f1_score(Y_test, Y_pred)

# Calculate confusion matrix
tn, fp, fn, tp = confusion_matrix(Y_test, Y_pred).ravel()

# Calculate DR and FPR
dr = tp / (tp + fn)  # Detection Rate
fpr = fp / (fp + tn)  # False Positive Rate

print(f"Accuracy on Test Set: {accuracy}")
print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F1-Score: {f1}")
print(f"Detection Rate (DR): {dr}")
print(f"False Positive Rate (FPR): {fpr}")

model.summary()

Start = time.time()
score = model.evaluate(X_train, Y_train, batch_size=32)
End = time.time()
Elapsed = End - Start
print('Total Testing Time : ' , str(Elapsed))

# Plot accuracy
plt.figure(figsize=(10, 6))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.grid(True)
plt.savefig('acc.png')
plt.show()

# Plot loss
plt.figure(figsize=(10, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')
plt.grid(True)
plt.savefig('loss.png')
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45718 entries, 0 to 45717
# Data columns (total 64 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   sAddress         45718 non-null  object
#  1   rAddress         45718 non-null  object
#  2   sMACs            45718 non-null  object
#  3   rMACs            45718 non-null  object
#  4   sIPs             44156 non-null  object
#  5   rIPs             44156 non-null  object
#  6   protocol         45718 non-null  object
#  7   startDate        45718 non-null  object
#  8   endDate          45718 non-null  object
#  9   start            45718 non-null  float64
#  10  end              45718 non-null  float64
#  11  startOffset      45718 non-null  float64
#  12  endOffset        45718 non-null  float64
#  13  duration         45718 non-null  float64
#  14  sPackets         45718 non-null  int64
#  15  rPackets         45718 non-null  int64
#  16  sBytesSum        45718 non-null  int64
#  17  rBytesSum        45718 non-null  int64
#  18  sBytesMax        44986 non-null  float64
#  19  rBytesMax        45056 non-null  float64
#  20  sBytesMin        44986 non-null  float64
#  21  rBytesMin        45056 non-null  float64
#  22  sBytesAvg        44986 non-null  float64
#  23  rBytesAvg        45056 non-null  float64
#  24  sLoad            45718 non-null  float64
#  25  rLoad            45718 non-null  float64
#  26  sPayloadSum      45718 non-null  int64
#  27  rPayloadSum      45718 non-null  int64
#  28  sPayloadMax      44986 non-null  float64
#  29  rPayloadMax      45056 non-null  float64
#  30  sPayloadMin      44986 non-null  float64
#  31  rPayloadMin      45056 non-null  float64
#  32  sPayloadAvg      44986 non-null  float64
#  33  rPayloadAvg      45056 non-null  float64
#  34  sInterPacketAvg  43317 non-null  float64
#  35  rInterPacketAvg  44444 non-null  float64
#  36  sttl             43860 non-null  float64
#  37  rttl             43983 non-null  float64
#  38  sAckRate         43860 non-null  float64
#  39  rAckRate         43983 non-null  float64
#  40  sUrgRate         43860 non-null  float64
#  41  rUrgRate         43983 non-null  float64
#  42  sFinRate         43860 non-null  float64
#  43  rFinRate         43983 non-null  float64
#  44  sPshRate         43860 non-null  float64
#  45  rPshRate         43983 non-null  float64
#  46  sSynRate         43860 non-null  float64
#  47  rSynRate         43983 non-null  float64
#  48  sRstRate         43860 non-null  float64
#  49  rRstRate         43983 non-null  float64
#  50  sWinTCP          43860 non-null  float64
#  51  rWinTCP          43983 non-null  float64
#  52  sFragmentRate    43870 non-null  float64
#  53  rFragmentRate    44145 non-null  float64
#  54  sAckDelayMax     43450 non-null  float64
#  55  rAckDelayMax     42443 non-null  float64
#  56  sAckDelayMin     43450 non-null  float64
#  57  rAckDelayMin     42443 non-null  float64
#  58  sAckDelayAvg     43450 non-null  float64
#  59  rAckDelayAvg     42443 non-null  float64
#  60  IT_B_Label       45718 non-null  int64
#  61  IT_M_Label       45718 non-null  object
#  62  NST_B_Label      45718 non-null  int64
#  63  NST_M_Label      45718 non-null  object
# dtypes: float64(45), int64(8), object(11)
# memory usage: 22.3+ MB
# None            IT_M_Label  NST_M_Label
# Normal          30236        36706
# ddos             4221         1934
# ip-scan           712          192
# mitm             3014         2584
# port-scan        3235         1944
# replay           4300         2358
# Input size:  56
# Epoch 1/50
# /opt/homebrew/lib/python3.11/site-packages/keras/src/layers/rnn/rnn.py:205: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# /opt/homebrew/lib/python3.11/site-packages/keras/src/optimizers/base_optimizer.py:34: UserWarning: Argument `decay` is no longer supported and will be ignored.
#   warnings.warn(
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 2s 766us/step - accuracy: 0.4992 - loss: 0.6933 - val_accuracy: 0.5051 - val_loss: 0.6930
# Epoch 2/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 646us/step - accuracy: 0.4988 - loss: 0.6932 - val_accuracy: 0.4949 - val_loss: 0.6929
# Epoch 3/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 642us/step - accuracy: 0.5058 - loss: 0.6930 - val_accuracy: 0.5051 - val_loss: 0.6929
# Epoch 4/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 645us/step - accuracy: 0.5123 - loss: 0.6931 - val_accuracy: 0.5051 - val_loss: 0.6918
# Epoch 5/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 641us/step - accuracy: 0.5433 - loss: 0.6916 - val_accuracy: 0.7609 - val_loss: 0.6871
# Epoch 6/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 645us/step - accuracy: 0.6248 - loss: 0.6708 - val_accuracy: 0.7749 - val_loss: 0.4682
# Epoch 7/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 668us/step - accuracy: 0.7326 - loss: 0.5091 - val_accuracy: 0.7931 - val_loss: 0.4153
# Epoch 8/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 642us/step - accuracy: 0.7694 - loss: 0.4532 - val_accuracy: 0.7938 - val_loss: 0.3807
# Epoch 9/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 647us/step - accuracy: 0.7709 - loss: 0.4203 - val_accuracy: 0.7938 - val_loss: 0.3634
# Epoch 10/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 644us/step - accuracy: 0.7757 - loss: 0.3949 - val_accuracy: 0.7957 - val_loss: 0.3523
# Epoch 11/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 657us/step - accuracy: 0.7803 - loss: 0.3808 - val_accuracy: 0.8110 - val_loss: 0.3378
# Epoch 12/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 648us/step - accuracy: 0.7925 - loss: 0.3715 - val_accuracy: 0.8254 - val_loss: 0.3264
# Epoch 13/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 648us/step - accuracy: 0.7950 - loss: 0.3649 - val_accuracy: 0.8136 - val_loss: 0.3307
# Epoch 14/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 651us/step - accuracy: 0.7994 - loss: 0.3584 - val_accuracy: 0.8344 - val_loss: 0.3191
# Epoch 15/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 661us/step - accuracy: 0.8086 - loss: 0.3579 - val_accuracy: 0.8221 - val_loss: 0.3151
# Epoch 16/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 649us/step - accuracy: 0.8225 - loss: 0.3397 - val_accuracy: 0.8368 - val_loss: 0.3050
# Epoch 17/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 651us/step - accuracy: 0.8184 - loss: 0.3402 - val_accuracy: 0.8301 - val_loss: 0.3089
# Epoch 18/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 665us/step - accuracy: 0.8205 - loss: 0.3376 - val_accuracy: 0.8351 - val_loss: 0.3156
# Epoch 19/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 649us/step - accuracy: 0.8115 - loss: 0.3468 - val_accuracy: 0.8377 - val_loss: 0.3027
# Epoch 20/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 647us/step - accuracy: 0.8188 - loss: 0.3332 - val_accuracy: 0.8339 - val_loss: 0.3043
# Epoch 21/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 650us/step - accuracy: 0.8179 - loss: 0.3310 - val_accuracy: 0.8169 - val_loss: 0.3224
# Epoch 22/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 673us/step - accuracy: 0.8185 - loss: 0.3299 - val_accuracy: 0.8242 - val_loss: 0.3132
# Epoch 23/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 650us/step - accuracy: 0.8140 - loss: 0.3320 - val_accuracy: 0.8271 - val_loss: 0.3068
# Epoch 24/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 646us/step - accuracy: 0.8135 - loss: 0.3291 - val_accuracy: 0.7919 - val_loss: 0.3258
# Epoch 25/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 665us/step - accuracy: 0.7973 - loss: 0.3397 - val_accuracy: 0.7973 - val_loss: 0.3213
# Epoch 26/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 649us/step - accuracy: 0.8041 - loss: 0.3363 - val_accuracy: 0.8346 - val_loss: 0.3088
# Epoch 27/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 651us/step - accuracy: 0.8081 - loss: 0.3333 - val_accuracy: 0.8089 - val_loss: 0.3178
# Epoch 28/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 666us/step - accuracy: 0.8084 - loss: 0.3300 - val_accuracy: 0.8346 - val_loss: 0.2961
# Epoch 29/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 651us/step - accuracy: 0.8169 - loss: 0.3224 - val_accuracy: 0.7990 - val_loss: 0.3093
# Epoch 30/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 656us/step - accuracy: 0.8103 - loss: 0.3241 - val_accuracy: 0.8368 - val_loss: 0.2922
# Epoch 31/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 663us/step - accuracy: 0.8146 - loss: 0.3229 - val_accuracy: 0.8167 - val_loss: 0.2888
# Epoch 32/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 679us/step - accuracy: 0.8173 - loss: 0.3197 - val_accuracy: 0.8349 - val_loss: 0.2978
# Epoch 33/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 655us/step - accuracy: 0.8136 - loss: 0.3227 - val_accuracy: 0.8346 - val_loss: 0.2964
# Epoch 34/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 678us/step - accuracy: 0.8148 - loss: 0.3200 - val_accuracy: 0.8358 - val_loss: 0.2965
# Epoch 35/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 655us/step - accuracy: 0.8135 - loss: 0.3201 - val_accuracy: 0.8306 - val_loss: 0.3114
# Epoch 36/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 663us/step - accuracy: 0.8172 - loss: 0.3186 - val_accuracy: 0.8351 - val_loss: 0.2882
# Epoch 37/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 677us/step - accuracy: 0.8193 - loss: 0.3147 - val_accuracy: 0.8323 - val_loss: 0.2909
# Epoch 38/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 658us/step - accuracy: 0.8224 - loss: 0.3118 - val_accuracy: 0.8363 - val_loss: 0.2935
# Epoch 39/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 672us/step - accuracy: 0.8168 - loss: 0.3130 - val_accuracy: 0.8363 - val_loss: 0.2866
# Epoch 40/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 661us/step - accuracy: 0.8213 - loss: 0.3127 - val_accuracy: 0.8372 - val_loss: 0.2876
# Epoch 41/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 656us/step - accuracy: 0.8203 - loss: 0.3075 - val_accuracy: 0.8379 - val_loss: 0.2855
# Epoch 42/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 674us/step - accuracy: 0.8194 - loss: 0.3036 - val_accuracy: 0.8304 - val_loss: 0.3057
# Epoch 43/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 655us/step - accuracy: 0.8212 - loss: 0.3123 - val_accuracy: 0.8365 - val_loss: 0.2920
# Epoch 44/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 660us/step - accuracy: 0.8174 - loss: 0.3124 - val_accuracy: 0.8353 - val_loss: 0.2868
# Epoch 45/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 675us/step - accuracy: 0.8153 - loss: 0.3103 - val_accuracy: 0.8327 - val_loss: 0.2940
# Epoch 46/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 663us/step - accuracy: 0.8161 - loss: 0.3099 - val_accuracy: 0.8330 - val_loss: 0.2869
# Epoch 47/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 679us/step - accuracy: 0.8227 - loss: 0.3075 - val_accuracy: 0.8351 - val_loss: 0.2899
# Epoch 48/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 661us/step - accuracy: 0.8156 - loss: 0.3087 - val_accuracy: 0.8384 - val_loss: 0.2770
# Epoch 49/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 662us/step - accuracy: 0.8176 - loss: 0.3074 - val_accuracy: 0.8318 - val_loss: 0.2791
# Epoch 50/50
# 1191/1191 ━━━━━━━━━━━━━━━━━━━━ 1s 682us/step - accuracy: 0.8209 - loss: 0.3050 - val_accuracy: 0.8351 - val_loss: 0.2768
# Total Training Time :  0:00:40.710003
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 0s 246us/step - accuracy: 0.8327 - loss: 0.2759
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 0s 457us/step
# Accuracy on Test Set: 0.8349685668945312
# Precision: 0.7660554522101161
# Recall: 0.9607821353182979
# F1-Score: 0.852439625431247
# Detection Rate (DR): 0.9607821353182979
# False Positive Rate (FPR): 0.2889180614812384
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape              ┃    Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 1, 32)             │     11,392 │
# ├─────────────────────────────────┼───────────────────────────┼────────────┤
# │ dropout (Dropout)               │ (None, 1, 32)             │          0 │
# ├─────────────────────────────────┼───────────────────────────┼────────────┤
# │ lstm_1 (LSTM)                   │ (None, 1, 16)             │      3,136 │
# ├─────────────────────────────────┼───────────────────────────┼────────────┤
# │ dropout_1 (Dropout)             │ (None, 1, 16)             │          0 │
# ├─────────────────────────────────┼───────────────────────────┼────────────┤
# │ lstm_2 (LSTM)                   │ (None, 8)                 │        800 │
# ├─────────────────────────────────┼───────────────────────────┼────────────┤
# │ dropout_2 (Dropout)             │ (None, 8)                 │          0 │
# ├─────────────────────────────────┼───────────────────────────┼────────────┤
# │ dense (Dense)                   │ (None, 1)                 │          9 │
# └─────────────────────────────────┴───────────────────────────┴────────────┘
#  Total params: 30,676 (119.83 KB)
#  Trainable params: 15,337 (59.91 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 15,339 (59.92 KB)
# 1323/1323 ━━━━━━━━━━━━━━━━━━━━ 0s 243us/step - accuracy: 0.8346 - loss: 0.2765
# Total Testing Time :  0.34201788902282715
